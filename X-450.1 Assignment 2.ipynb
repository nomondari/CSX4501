# %% [markdown]
# # Title
#
# name

# %%
import business_dynamics
record = business_dynamics.get_record()

# %%
record
# Out:
# [{'State': 'Alabama',
#   'Year': 1978,
#   'Data': {'DHS Denominator': 972627,
#    'Number of Firms': 54597,
#    'Calculated': {'Net Job Creation': 74178,
#     'Net Job Creation Rate': 7.627,
#     'Reallocation Rate': 29.183},
#    'Establishments': {'Entered': 10457,
#     'Entered Rate': 16.375,
#     'Exited': 7749,
#     'Exited Rate': 12.135,
#     'Physical Locations': 65213},
#    'Firm Exits': {'Count': 5248,
#     'Establishment Exit': 5329,
#     'Employments': 28257},
#    'Job Creation': {'Births': 76167,
#     'Continuers': 139930,
#     'Count': 216097,
#     'Rate': 22.218,
#     'Rate/Births': 7.831},
#    'Job Destruction': {'Continuers': 81829,
#     'Count': 141919,
#     'Deaths': 60090,
#     'Rate': 14.591,
#     'Rate/Deaths': 6.178}}},
#  {'State': 'Alabama',
#   'Year': 1979,
#   'Data': {'DHS Denominator': 1037995,
#    'Number of Firms': 55893,
#    'Calculated': {'Net Job Creation': 58099,
#     'Net Job Creation Rate': 5.597,
# ...

# %%
type(record)
# Out:
# list

# %%
len(record)
# Out:
# 1927

# %%
record[0]
# Out:
# {'State': 'Alabama',
#  'Year': 1978,
#  'Data': {'DHS Denominator': 972627,
#   'Number of Firms': 54597,
#   'Calculated': {'Net Job Creation': 74178,
#    'Net Job Creation Rate': 7.627,
#    'Reallocation Rate': 29.183},
#   'Establishments': {'Entered': 10457,
#    'Entered Rate': 16.375,
#    'Exited': 7749,
#    'Exited Rate': 12.135,
#    'Physical Locations': 65213},
#   'Firm Exits': {'Count': 5248,
#    'Establishment Exit': 5329,
#    'Employments': 28257},
#   'Job Creation': {'Births': 76167,
#    'Continuers': 139930,
#    'Count': 216097,
#    'Rate': 22.218,
#    'Rate/Births': 7.831},
#   'Job Destruction': {'Continuers': 81829,
#    'Count': 141919,
#    'Deaths': 60090,
#    'Rate': 14.591,
#    'Rate/Deaths': 6.178}}}

# %%
firstrecord = record[0]

# %%
firstrecord
# Out:
# {'State': 'Alabama',
#  'Year': 1978,
#  'Data': {'DHS Denominator': 972627,
#   'Number of Firms': 54597,
#   'Calculated': {'Net Job Creation': 74178,
#    'Net Job Creation Rate': 7.627,
#    'Reallocation Rate': 29.183},
#   'Establishments': {'Entered': 10457,
#    'Entered Rate': 16.375,
#    'Exited': 7749,
#    'Exited Rate': 12.135,
#    'Physical Locations': 65213},
#   'Firm Exits': {'Count': 5248,
#    'Establishment Exit': 5329,
#    'Employments': 28257},
#   'Job Creation': {'Births': 76167,
#    'Continuers': 139930,
#    'Count': 216097,
#    'Rate': 22.218,
#    'Rate/Births': 7.831},
#   'Job Destruction': {'Continuers': 81829,
#    'Count': 141919,
#    'Deaths': 60090,
#    'Rate': 14.591,
#    'Rate/Deaths': 6.178}}}

# %%
firstrecord.keys()
# Out:
# dict_keys(['State', 'Year', 'Data'])

# %%
firstrecord['State']
# Out:
# 'Alabama'

# %%
record[0]['State']
# Out:
# 'Alabama'

# %%
for i in record:
    print(i)
# Out:
# {'State': 'Alabama', 'Year': 1978, 'Data': {'DHS Denominator': 972627, 'Number of Firms': 54597, 'Calculated': {'Net Job Creation': 74178, 'Net Job Creation Rate': 7.627, 'Reallocation Rate': 29.183}, 'Establishments': {'Entered': 10457, 'Entered Rate': 16.375, 'Exited': 7749, 'Exited Rate': 12.135, 'Physical Locations': 65213}, 'Firm Exits': {'Count': 5248, 'Establishment Exit': 5329, 'Employments': 28257}, 'Job Creation': {'Births': 76167, 'Continuers': 139930, 'Count': 216097, 'Rate': 22.218, 'Rate/Births': 7.831}, 'Job Destruction': {'Continuers': 81829, 'Count': 141919, 'Deaths': 60090, 'Rate': 14.591, 'Rate/Deaths': 6.178}}}
# ...

# %%
for i in record:
    if i['State'] == 'California' and i['Year'] == 1978:
        print(i['Data'])
# Out:
# {'DHS Denominator': 539707, 'Number of Firms': 36821, 'Calculated': {'Net Job Creation': 49070, 'Net Job Creation Rate': 9.092, 'Reallocation Rate': 27.328}, 'Establishments': {'Entered': 7154, 'Entered Rate': 17.401, 'Exited': 5227, 'Exited Rate': 12.714, 'Physical Locations': 42075}, 'Firm Exits': {'Count': 3858, 'Establishment Exit': 3884, 'Employments': 17124}, 'Job Creation': {'Births': 49204, 'Continuers': 73612, 'Count': 122816, 'Rate': 22.756, 'Rate/Births': 9.117}, 'Job Destruction': {'Continuers': 41945, 'Count': 73746, 'Deaths': 31801, 'Rate': 13.664, 'Rate/Deaths': 5.892}}

# %%
for i in record:
    if i['State'] == 'California' and i['Year'] > 1978 & i['Year'] < 1983:
        print(sum['Data']['Number of Firms']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NOMOND~1\AppData\Local\Temp/ipykernel_1824/91819337.py in <module>
#       1 for i in record:
#       2     if i['State'] == 'California' and i['Year'] > 1978 & i['Year'] < 1983:
# ----> 3         print(sum(i['Data']['Number of Firms']))
#       4
#
# TypeError: 'int' object is not iterable

# %%
sum = 0
for i in [1,2,3]:
    sum += i
print(sum)
# Out:
# 6

# %%
print("Hello Teacher!")
# Out:
# Hello Teacher!

# %%
import pandas as pd

# %%
df = pd.read_csv('business_dynamics.csv')

# %%
df
# Out:
#         State  Year  Data.DHS Denominator  Data.Number of Firms  \
# 0     Alabama  1978                972627                 54597
# 1     Alabama  1979               1037995                 55893
# 2     Alabama  1980               1064141                 54838
# 3     Alabama  1981               1051448                 54791
# 4     Alabama  1982               1037728                 53219
# ...       ...   ...                   ...                   ...
# 1922  Wyoming  2014               3121032                133693
# 1923  Wyoming  2015               3173176                134663
# 1924  Wyoming  2016               3234346                135969
# 1925  Wyoming  2017               3277473                136785
# 1926  Wyoming  2018               3337281                137189
#
#       Data.Calculated.Net Job Creation  Data.Calculated.Net Job Creation Rate  \
# 0                                74178                                  7.627
# ...

# %%
=min(df(column))
# Out:
#   File "C:\Users\NOMOND~1\AppData\Local\Temp/ipykernel_22028/3819832033.py", line 1
#     =min(df(column))
#     ^
# SyntaxError: invalid syntax
